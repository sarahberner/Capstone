# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('./hearthstone_collectible_df.csv')
df.head().T
# Out:
#                                                                  0  \
# artist                                                         NaN
# attack                                                         NaN
# cardId                                                     HERO_09
# cardSet                                                      Basic
# collectible                                                   True
# cost                                                           NaN
# dbfId                                                          813
# durability                                                     NaN
# faction                                                    Neutral
# flavor                                                         NaN
# health                                                          30
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                                  Anduin Wrynn
# playerClass                                                 Priest
# race                                                           NaN
# rarity                                                        Free
# text                                                           NaN
# type                                                          Hero
# elite                                                          NaN
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                                  1  \
# artist                                                         NaN
# attack                                                         NaN
# cardId                                                     HERO_01
# cardSet                                                      Basic
# collectible                                                   True
# cost                                                           NaN
# dbfId                                                            7
# durability                                                     NaN
# faction                                                    Neutral
# flavor                                                         NaN
# health                                                          30
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                            Garrosh Hellscream
# playerClass                                                Warrior
# race                                                           NaN
# rarity                                                        Free
# text                                                           NaN
# type                                                          Hero
# elite                                                          NaN
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                                  2  \
# artist                                                         NaN
# attack                                                         NaN
# cardId                                                     HERO_07
# cardSet                                                      Basic
# collectible                                                   True
# cost                                                           NaN
# dbfId                                                          893
# durability                                                     NaN
# faction                                                    Neutral
# flavor                                                         NaN
# health                                                          30
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                                       Gul'dan
# playerClass                                                Warlock
# race                                                           NaN
# rarity                                                        Free
# text                                                           NaN
# type                                                          Hero
# elite                                                          NaN
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                                  3  \
# artist                                                         NaN
# attack                                                         NaN
# cardId                                                     HERO_08
# cardSet                                                      Basic
# collectible                                                   True
# cost                                                           NaN
# dbfId                                                          637
# durability                                                     NaN
# faction                                                    Neutral
# flavor                                                         NaN
# health                                                          30
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                              Jaina Proudmoore
# playerClass                                                   Mage
# race                                                           NaN
# rarity                                                        Free
# text                                                           NaN
# type                                                          Hero
# elite                                                          NaN
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                                  4
# artist                                                         NaN
# attack                                                         NaN
# cardId                                                     HERO_06
# cardSet                                                      Basic
# collectible                                                   True
# cost                                                           NaN
# dbfId                                                          274
# durability                                                     NaN
# faction                                                    Neutral
# flavor                                                         NaN
# health                                                          30
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                           Malfurion Stormrage
# playerClass                                                  Druid
# race                                                           NaN
# rarity                                                        Free
# text                                                           NaN
# type                                                          Hero
# elite                                                          NaN
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN

# %%
df.shape
# Out:
# (2012, 27)

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Things to clean up:
#  - the elite column seems to be true if the card is a legendary, empty otherwise. Check this, and if so, it's extraneous information, so we can just drop the elite column.
#  - Not every card has a race, so we can change NaNs to 'general', as is documented here:
#   https://hearthstone.gamepedia.com/Minion
#  - Change NaN  in 'text' to empty string (if the card has no text)
#  - Faction is either 'Horde', 'Alliance', or 'Neutral' - change all NaNs to neutral.

# %%
df[(df['elite'].isna()) & (df['rarity'] == 'Legendary')]
# Out:
# Empty DataFrame
# Columns: [artist, attack, cardId, cardSet, collectible, cost, dbfId, durability, faction, flavor, health, howToGet, howToGetGold, img, imgGold, locale, mechanics, name, playerClass, race, rarity, text, type, elite, classes, multiClassGroup, armor]
# Index: []
#
# [0 rows x 27 columns]

# %%
# they're all the same - we can drop the elite column!

df.drop(columns = ['elite'], inplace = True)

# %% [markdown]
# Now let's change the NaNs to general in the race column:

# %%
df['race'].value_counts()
# Out:
# Beast        161
# Mech         104
# Elemental     77
# Demon         47
# Dragon        44
# Murloc        33
# Pirate        27
# Totem          6
# All            1
# Name: race, dtype: int64

# %%
df['race'] = df['race'].fillna('General')

# %%
df['race'].value_counts().sum()
# Out:
# 2012

# %% [markdown]
# And now the empty strings in text:

# %%
df['text'] = df['text'].fillna(' ')

# %%
df.text.isnull().sum()
# Out:
# 0

# %% [markdown]
# Finally the empty strings in faction:

# %%
df['faction'] = df['faction'].fillna('Neutral')

# %%
df.faction.value_counts()
# Out:
# Neutral     1935
# Alliance      51
# Horde         26
# Name: faction, dtype: int64

# %% [markdown]
# And we can drop the redundant 'collectible' column:

# %%
df.drop(columns = ['collectible'], inplace = True)

# %%
df.shape
# Out:
# (2012, 25)

# %%
df[df['durability'].notna()].T
# Out:
#                                                               29    \
# artist                                                  Glenn Rane
# attack                                                           1
# cardId                                                     CS2_091
# cardSet                                                      Basic
# cost                                                             1
# dbfId                                                          383
# durability                                                       4
# faction                                                    Neutral
# flavor           Prince Malchezaar was a collector of rare weap...
# health                                                         NaN
# howToGet                                      Unlocked at Level 1.
# howToGetGold                                 Unlocked at Level 36.
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                               Light's Justice
# playerClass                                                Paladin
# race                                                       General
# rarity                                                        Free
# text
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               73    \
# artist                                              Lucas Graciano
# attack                                                           3
# cardId                                                     CS2_106
# cardSet                                                      Basic
# cost                                                             3
# dbfId                                                          401
# durability                                                       2
# faction                                                    Neutral
# flavor           During times of tranquility and harmony, this ...
# health                                                         NaN
# howToGet                                      Unlocked at Level 1.
# howToGetGold                                 Unlocked at Level 49.
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                                 Fiery War Axe
# playerClass                                                Warrior
# race                                                       General
# rarity                                                        Free
# text
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               110   \
# artist                                                   Ryan Sook
# attack                                                           4
# cardId                                                     CS2_097
# cardSet                                                      Basic
# cost                                                             4
# dbfId                                                          847
# durability                                                       2
# faction                                                    Neutral
# flavor           It Slices, it Dices. You can cut a tin can wit...
# health                                                         NaN
# howToGet                                      Unlocked at Level 2.
# howToGetGold                                 Unlocked at Level 40.
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                           Truesilver Champion
# playerClass                                                Paladin
# race                                                       General
# rarity                                                        Free
# text             Whenever your hero attacks, restore #2_Health ...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               113   \
# artist                                             Stefan Kopinski
# attack                                                           5
# cardId                                                     CS2_112
# cardSet                                                      Basic
# cost                                                             5
# dbfId                                                          304
# durability                                                       2
# faction                                                    Neutral
# flavor                    No… actually you should fear the Reaper.
# health                                                         NaN
# howToGet                                     Unlocked at Level 10.
# howToGetGold                                 Unlocked at Level 51.
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                               Arcanite Reaper
# playerClass                                                Warrior
# race                                                       General
# rarity                                                        Free
# text
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               114   \
# artist                                                 Brian Huang
# attack                                                           3
# cardId                                                     CS2_080
# cardSet                                                      Basic
# cost                                                             5
# dbfId                                                          421
# durability                                                       4
# faction                                                    Neutral
# flavor           Guaranteed to have been owned by a real assass...
# health                                                         NaN
# howToGet                                      Unlocked at Level 2.
# howToGetGold                                 Unlocked at Level 32.
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                              Assassin's Blade
# playerClass                                                  Rogue
# race                                                       General
# rarity                                                        Free
# text
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               225   \
# artist                                                 Nate Bowden
# attack                                                           2
# cardId                                                     EX1_247
# cardSet                                                    Classic
# cost                                                             2
# dbfId                                                          960
# durability                                                       3
# faction                                                    Neutral
# flavor                                      Yo, that's a nice axe.
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                   [{'name': 'Overload'}]
# name                                               Stormforged Axe
# playerClass                                                 Shaman
# race                                                       General
# rarity                                                      Common
# text                                          <b>Overload:</b> (1)
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               239   \
# artist                                        Cyril Van Der Haegen
# attack                                                           3
# cardId                                                     EX1_536
# cardSet                                                    Classic
# cost                                                             3
# dbfId                                                         1662
# durability                                                       2
# faction                                                    Neutral
# flavor           First Lesson: Put the pointy end in the other ...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                     [{'name': 'Secret'}]
# name                                                 Eaglehorn Bow
# playerClass                                                 Hunter
# race                                                       General
# rarity                                                        Rare
# text             [x]Whenever a friendly\n<b>Secret</b> is revea...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               264   \
# artist                                                 Daren Bader
# attack                                                           2
# cardId                                                     EX1_133
# cardSet                                                    Classic
# cost                                                             3
# dbfId                                                          391
# durability                                                       2
# faction                                                    Neutral
# flavor           Perdition's Blade is Ragnaros's back-up weapon...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics               [{'name': 'Battlecry'}, {'name': 'Combo'}]
# name                                             Perdition's Blade
# playerClass                                                  Rogue
# race                                                       General
# rarity                                                        Rare
# text             <b>Battlecry:</b> Deal 1 damage. <b>Combo:</b>...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               273   \
# artist                                              Efrem Palacios
# attack                                                           1
# cardId                                                     EX1_366
# cardSet                                                    Classic
# cost                                                             3
# dbfId                                                          643
# durability                                                       5
# faction                                                    Neutral
# flavor                                 I dub you Sir Loin of Beef!
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                              Sword of Justice
# playerClass                                                Paladin
# race                                                       General
# rarity                                                        Epic
# text             After you summon a minion, give it +1/+1 and t...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               317   \
# artist                                               John Polidora
# attack                                                           2
# cardId                                                     EX1_567
# cardSet                                                    Classic
# cost                                                             5
# dbfId                                                          352
# durability                                                       8
# faction                                                    Neutral
# flavor           Orgrim Doomhammer gave this legendary weapon t...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics             [{'name': 'Overload'}, {'name': 'Windfury'}]
# name                                                    Doomhammer
# playerClass                                                 Shaman
# race                                                       General
# rarity                                                        Epic
# text                                <b>Windfury, Overload:</b> (2)
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                        ...                          \
# artist                                 ...
# attack                                 ...
# cardId                                 ...
# cardSet                                ...
# cost                                   ...
# dbfId                                  ...
# durability                             ...
# faction                                ...
# flavor                                 ...
# health                                 ...
# howToGet                               ...
# howToGetGold                           ...
# img                                    ...
# imgGold                                ...
# locale                                 ...
# mechanics                              ...
# name                                   ...
# playerClass                            ...
# race                                   ...
# rarity                                 ...
# text                                   ...
# type                                   ...
# classes                                ...
# multiClassGroup                        ...
# armor                                  ...
#
#                                                               1831  \
# artist                                                     J. Axer
# attack                                                           0
# cardId                                                     TRL_317
# cardSet                                         Rastakhan's Rumble
# cost                                                             5
# dbfId                                                        50086
# durability                                                       0
# faction                                                    Neutral
# flavor           If you’re burning and you know it, wave your h...
# health                                                           0
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                   [{'name': 'Overkill'}]
# name                                                    Blast Wave
# playerClass                                                   Mage
# race                                                       General
# rarity                                                        Epic
# text             Deal $2 damage to_all minions.\n<b>Overkill</b...
# type                                                         Spell
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1834  \
# artist                                     M. Alvares & M. Azevedo
# attack                                                           3
# cardId                                                     TRL_304
# cardSet                                         Rastakhan's Rumble
# cost                                                             5
# dbfId                                                        50014
# durability                                                       3
# faction                                                    Neutral
# flavor           Only two things in life are certain: death and...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                   [{'name': 'Overkill'}]
# name                                             Farraki Battleaxe
# playerClass                                                Paladin
# race                                                       General
# rarity                                                        Rare
# text             <b>Overkill:</b> Give a minion in your hand +2...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1851  \
# artist                                                  Jason Kang
# attack                                                           4
# cardId                                                     TRL_325
# cardSet                                         Rastakhan's Rumble
# cost                                                             6
# dbfId                                                        50056
# durability                                                       4
# faction                                                    Neutral
# flavor           “Griftah here with de Sul’chop. One chop, you ...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                   [{'name': 'Overkill'}]
# name                                                    Sul'thraze
# playerClass                                                Warrior
# race                                                       General
# rarity                                                        Epic
# text                        <b>Overkill</b>: You may attack again.
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1904  \
# artist                                            Vladimir Kafanov
# attack                                                           0
# cardId                                                     DAL_568
# cardSet                                            Rise of Shadows
# cost                                                             2
# dbfId                                                        52490
# durability                                                       0
# faction                                                    Neutral
# flavor                        Some might call this a lightforgery.
# health                                                           0
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics           [{'name': 'Twinspell'}, {'name': 'Lifesteal'}]
# name                                          Lightforged Blessing
# playerClass                                                Paladin
# race                                                       General
# rarity                                                      Common
# text             <b>Twinspell</b>\nGive a friendly minion <b>Li...
# type                                                         Spell
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1908  \
# artist                                                  Vlad Botos
# attack                                                           2
# cardId                                                     DAL_571
# cardSet                                            Rise of Shadows
# cost                                                             2
# dbfId                                                        52496
# durability                                                       2
# faction                                                    Neutral
# flavor                        It knows every secret you have left.
# health                                                           0
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics              [{'name': 'Battlecry'}, {'name': 'Secret'}]
# name                                              Mysterious Blade
# playerClass                                                Paladin
# race                                                       General
# rarity                                                        Rare
# text             <b>Battlecry:</b> If you control a\n<b>Secret<...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1925  \
# artist                                                Jakub Kasper
# attack                                                           0
# cardId                                                     DAL_177
# cardSet                                            Rise of Shadows
# cost                                                             3
# dbfId                                                        51971
# durability                                                       0
# faction                                                    Neutral
# flavor                       If only you’d let it go to voicemail…
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                  [{'name': 'Twinspell'}]
# name                                            Conjurer's Calling
# playerClass                                                   Mage
# race                                                       General
# rarity                                                        Rare
# text             <b>Twinspell</b>\nDestroy a minion. Summon 2 m...
# type                                                         Spell
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1942  \
# artist                                                  Jim Nelson
# attack                                                           2
# cardId                                                     DAL_563
# cardSet                                            Rise of Shadows
# cost                                                             4
# dbfId                                                        52482
# durability                                                       0
# faction                                                    Neutral
# flavor                      Eager to please, even if it kills him.
# health                                                           2
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                [{'name': 'Deathrattle'}]
# name                                               Eager Underling
# playerClass                                                Warlock
# race                                                       General
# rarity                                                        Rare
# text             <b>Deathrattle:</b> Give two random friendly m...
# type                                                        Minion
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1958  \
# artist                                                  Jason Kang
# attack                                                           4
# cardId                                                     DAL_720
# cardSet                                            Rise of Shadows
# cost                                                             4
# dbfId                                                        52617
# durability                                                       2
# faction                                                    Neutral
# flavor           Kobolds informally refer to its effect as a de...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                [{'name': 'Deathrattle'}]
# name                                                   Waggle Pick
# playerClass                                                  Rogue
# race                                                       General
# rarity                                                        Epic
# text             [x]<b>Deathrattle:</b> Return\na random friend...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1959  \
# artist                                                  Akkapoj T.
# attack                                                           3
# cardId                                                     DAL_063
# cardSet                                            Rise of Shadows
# cost                                                             4
# dbfId                                                        51738
# durability                                                       2
# faction                                                    Neutral
# flavor           Whoso pulleth out this wrench from the toolbox...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                                                      NaN
# name                                                 Wrenchcalibur
# playerClass                                                Warrior
# race                                                       General
# rarity                                                        Epic
# text             After your hero attacks, shuffle a Bomb into y...
# type                                                        Weapon
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
#                                                               1981
# artist                                     L. Lullabi & K. Turovec
# attack                                                           0
# cardId                                                     DAL_378
# cardSet                                            Rise of Shadows
# cost                                                             6
# dbfId                                                        52089
# durability                                                       0
# faction                                                    Neutral
# flavor           The Kirin Tor have always been lax in enforcin...
# health                                                         NaN
# howToGet                                                       NaN
# howToGetGold                                                   NaN
# img              http://media.services.zam.com/v1/media/byName/...
# imgGold          http://media.services.zam.com/v1/media/byName/...
# locale                                                        enUS
# mechanics                [{'name': 'Twinspell'}, {'name': 'Rush'}]
# name                                             Unleash the Beast
# playerClass                                                 Hunter
# race                                                       General
# rarity                                                        Rare
# text             <b>Twinspell</b>\nSummon a 5/5 Wyvern with <b>...
# type                                                         Spell
# classes                                                        NaN
# multiClassGroup                                                NaN
# armor                                                          NaN
#
# [25 rows x 73 columns]

# %%
df.columns
# Out:
# Index(['artist', 'attack', 'cardId', 'cardSet', 'cost', 'dbfId', 'durability',
#        'faction', 'flavor', 'health', 'howToGet', 'howToGetGold', 'img',
#        'imgGold', 'locale', 'mechanics', 'name', 'playerClass', 'race',
#        'rarity', 'text', 'type', 'classes', 'multiClassGroup', 'armor'],
#       dtype='object')

# %%
df['cardSet'].value_counts()
# Out:
# Classic                         237
# Basic                           142
# Journey to Un'Goro              135
# Rise of Shadows                 135
# The Boomsday Project            135
# Rastakhan's Rumble              135
# Kobolds & Catacombs             135
# Knights of the Frozen Throne    135
# Whispers of the Old Gods        134
# The Grand Tournament            132
# Mean Streets of Gadgetzan       132
# The Witchwood                   129
# Goblins vs Gnomes               123
# One Night in Karazhan            45
# The League of Explorers          45
# Blackrock Mountain               31
# Naxxramas                        30
# Hall of Fame                     22
# Name: cardSet, dtype: int64

# %%
value_count_list = ['attack',  'cardSet', 'cost', 
       'durability', 'faction',  'health', 
       'playerClass', 'race',
       'rarity',  'type',  'classes', 'armor']

for column in value_count_list:
    print(f'The {column} values are: ')
    print(df[column].value_counts())
    print('')
# Out:
# The attack values are:
# 2.0     335
# 3.0     308
# 4.0     208
# 1.0     195
# 5.0     167
# 6.0      73
# 0.0      69
# 7.0      52
# 8.0      33
# 9.0      14
# 10.0      4
# 12.0      3
# 20.0      1
# Name: attack, dtype: int64
#
# The cardSet values are:
# Classic                         237
# Basic                           142
# Journey to Un'Goro              135
# Rise of Shadows                 135
# The Boomsday Project            135
# Rastakhan's Rumble              135
# Kobolds & Catacombs             135
# Knights of the Frozen Throne    135
# Whispers of the Old Gods        134
# The Grand Tournament            132
# Mean Streets of Gadgetzan       132
# The Witchwood                   129
# Goblins vs Gnomes               123
# One Night in Karazhan            45
# The League of Explorers          45
# Blackrock Mountain               31
# Naxxramas                        30
# Hall of Fame                     22
# Name: cardSet, dtype: int64
#
# The cost values are:
# 3.0     365
# 2.0     361
# 4.0     316
# 5.0     248
# 1.0     239
# 6.0     173
# 7.0     111
# 8.0      76
# 9.0      45
# 10.0     31
# 0.0      31
# 12.0      4
# 25.0      1
# 11.0      1
# 20.0      1
# Name: cost, dtype: int64
#
# The durability values are:
# 2.0    30
# 3.0    21
# 4.0     9
# 0.0     8
# 1.0     2
# 5.0     2
# 8.0     1
# Name: durability, dtype: int64
#
# The faction values are:
# Neutral     1935
# Alliance      51
# Horde         26
# Name: faction, dtype: int64
#
# The health values are:
# 3.0     252
# 4.0     243
# 2.0     208
# 5.0     185
# 1.0     162
# 6.0     137
# 7.0      83
# 8.0      65
# 0.0      21
# 30.0     21
# 9.0      20
# 12.0     11
# 10.0      8
# 11.0      2
# 14.0      2
# 20.0      1
# 15.0      1
# Name: health, dtype: int64
#
# The playerClass values are:
# Neutral    747
# Mage       142
# Hunter     141
# Warlock    141
# Rogue      141
# Paladin    140
# Priest     140
# Druid      140
# Warrior    140
# Shaman     140
# Name: playerClass, dtype: int64
#
# The race values are:
# General      1512
# Beast         161
# Mech          104
# Elemental      77
# Demon          47
# Dragon         44
# Murloc         33
# Pirate         27
# Totem           6
# All             1
# Name: race, dtype: int64
#
# The rarity values are:
# Common       713
# Rare         519
# Epic         339
# Legendary    299
# Free         142
# Name: rarity, dtype: int64
#
# The type values are:
# Minion    1378
# Spell      548
# Weapon      65
# Hero        21
# Name: type, dtype: int64
#
# The classes values are:
# ['Druid', 'Rogue', 'Shaman']        3
# ['Hunter', 'Paladin', 'Warrior']    3
# ['Mage', 'Priest', 'Warlock']       3
# Name: classes, dtype: int64
#
# The armor values are:
# 5.0    11
# 7.0     1
# 1.0     1
# Name: armor, dtype: int64

# %%
def f(x):
    if x in range(21):
        return 1
    else:
        return 0

# %%
df['attack_true'] = df['attack'].map(f)

# %%
df['attack_true'].value_counts()
# Out:
# 1    1462
# 0     550
# Name: attack_true, dtype: int64

# %%
pd.get_dummies(df, columns=['intl_plan','vmail_plan'], drop_first=True)

# %% [markdown]
# dummy columns for each feature that has a nan (attack, armor, health, etc)
#
# dummy all the attack/health/durability/armor values
#
#
# from the given cards find the best deck
# gym.ai
#
# monte carlo simulations on decks (random plays)
#
#
# network analysis (clustering)*** this is the way to go!
